# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
fix , ax=plt.subplots(figsize=(5,5))
x=range(1,5)
y=[3,4,5,6]
ax.plot(x,y)

ax.set(title="first plot",xlabel='x-axis',ylabel='y-axis')
# fig.savefig()
plt.grid()

plt.show()

# %%
import numpy as np

# %%
x=np.linspace(0,10,100)

fix,ax=plt.subplots()
ax.plot(x,x**2)

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.exp(x))

# %%
fig,ax=plt.subplots()
ax.scatter(x,np.sin(x))

# %%
x={'Almond':10,'Peanut':8,'Cashew':12}

fig ,ax=plt.subplots()
ax.bar(x.keys(),x.values())
ax.set(title='Butter')

plt.show()

# %%
fig,ax=plt.subplots()
ax.barh(list(x.keys()),list(x.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
x=np.random.randn(1000)

fig,ax=plt.subplots()
ax.hist(x)
plt.show()

# %%
nut={'Almond':10,'Peanut':8,'Cashew':12}

fig, ((ax1,ax2),(ax3,ax4))=plt.subplots(nrows=2,ncols=2,figsize=(10,10))

ax1.plot(x,x/2)
ax2.scatter(np.random.random(10),np.random.random(10))
ax3.bar(nut.keys(),nut.values())
ax4.hist(np.random.randn(1000))
fig.suptitle("super ")
ax1.set(xlabel="fsdf")
# Out:
# [Text(0.5, 0, 'fsdf')]

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(10,10))

ax[0,0].plot(x,x/2)
ax[0,1].scatter(np.random.random(10),np.random.random(10))
ax[1,0].bar(nut.keys(),nut.values())
ax[1,1].hist(np.random.randn(1000))
# Out:
# (array([  7.,  44.,  93., 170., 241., 215., 134.,  66.,  25.,   5.]),
#  array([-2.83831846, -2.25167866, -1.66503885, -1.07839905, -0.49175925,
#          0.09488056,  0.68152036,  1.26816017,  1.85479997,  2.44143977,
#          3.02807958]),
#  <BarContainer object of 10 artists>)
